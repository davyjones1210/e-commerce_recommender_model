# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from mlxtend) (2.3.1)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from mlxtend) (3.9.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->mlxtend) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\minal\miniconda3\envs\dsi_participant\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("combined_unique.csv", encoding='latin1')
print(df.shape)
print(df.head())
df.info()
# Out:
# C:\Users\Minal\AppData\Local\Temp\ipykernel_27820\4056450116.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("combined_unique.csv", encoding='latin1')
# (1008898, 8)
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008898 entries, 0 to 1008897
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1008898 non-null  object
#  1   StockCode    1008898 non-null  object
#  2   Description  1008898 non-null  object
#  3   Quantity     1008898 non-null  int64
#  4   InvoiceDate  1008898 non-null  object
#  5   Price        1008898 non-null  float64
#  6   Customer ID  779495 non-null   float64
#  7   Country      1008898 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 61.6+ MB

# %%
#convert InvoiceDate to datetime format
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format='%d-%m-%Y %H:%M', errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008898 entries, 0 to 1008897
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1008898 non-null  object
#  1   StockCode    1008898 non-null  object
#  2   Description  1008898 non-null  object
#  3   Quantity     1008898 non-null  int64
#  4   InvoiceDate  0 non-null        datetime64[ns]
#  5   Price        1008898 non-null  float64
#  6   Customer ID  779495 non-null   float64
#  7   Country      1008898 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 61.6+ MB

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Subset to avoid memory issues
sample_invoices = df['Invoice'].drop_duplicates().sample(5000, random_state=42)
df_sample = df[df['Invoice'].isin(sample_invoices)]

# Create basket matrix (Invoice × Description)
basket = (
    df_sample.groupby(['Invoice', 'Description'])['Quantity']
    .sum()
    .unstack()
    .fillna(0)
)
basket = (basket > 0).astype(int)

# Apriori model
frequent_items = apriori(basket, min_support=0.02, use_colnames=True)

# Generate rules and compute metrics
rules = association_rules(frequent_items, metric="lift", min_threshold=1.0)

# Filter rules for meaningful recommendations
rules = rules[
    (rules['support'] >= 0.02) &  # at least 2% of transactions
    (rules['confidence'] >= 0.2) &  # at least 20% confidence
    (rules['lift'] >= 2)          # stronger-than-chance relationships
]

# Sort by lift (best recommendations first)
rules = rules.sort_values('lift', ascending=False)

# Show top 10 strongest associations
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#                              antecedents  \
# 8       (PINK REGENCY TEACUP AND SAUCER)
# 9      (GREEN REGENCY TEACUP AND SAUCER)
# 10    (ROSES REGENCY TEACUP AND SAUCER )
# 11     (GREEN REGENCY TEACUP AND SAUCER)
# 34      (PINK REGENCY TEACUP AND SAUCER)
# 35    (ROSES REGENCY TEACUP AND SAUCER )
# 3            (ALARM CLOCK BAKELIKE RED )
# 2           (ALARM CLOCK BAKELIKE GREEN)
# 7                 (DOLLY GIRL LUNCH BOX)
# 6                  (SPACEBOY LUNCH BOX )
# 38      (SWEETHEART CERAMIC TRINKET BOX)
# 39      (STRAWBERRY CERAMIC TRINKET BOX)
# 14            (LOVE BUILDING BLOCK WORD)
# 15            (HOME BUILDING BLOCK WORD)
# 42   (WOODEN PICTURE FRAME WHITE FINISH)
# 43         (WOODEN FRAME ANTIQUE WHITE )
# 12               (HEART OF WICKER LARGE)
# 13               (HEART OF WICKER SMALL)
# 0          (60 TEATIME FAIRY CAKE CASES)
# 1   (PACK OF 60 PINK PAISLEY CAKE CASES)
# 33          (LUNCH BAG SPACEBOY DESIGN )
# 32                  (LUNCH BAG WOODLAND)
# 31             (LUNCH BAG  BLACK SKULL.)
# 30                  (LUNCH BAG WOODLAND)
# 18             (JUMBO BAG PINK POLKADOT)
# 19             (JUMBO BAG RED RETROSPOT)
# 28                 (LUNCH BAG CARS BLUE)
# 29             (LUNCH BAG  BLACK SKULL.)
# 26   (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 27              (JUMBO STORAGE BAG SUKI)
# 21                (JUMBO BAG STRAWBERRY)
# 20             (JUMBO BAG RED RETROSPOT)
# 17      (JUMBO  BAG BAROQUE BLACK WHITE)
# 16             (JUMBO BAG RED RETROSPOT)
# 22             (JUMBO BAG RED RETROSPOT)
# 23   (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 24             (JUMBO BAG RED RETROSPOT)
# 25              (JUMBO STORAGE BAG SUKI)
# 37    (RED HANGING HEART T-LIGHT HOLDER)
# 36  (WHITE HANGING HEART T-LIGHT HOLDER)
# 41         (WOODEN FRAME ANTIQUE WHITE )
#
#                              consequents  support  confidence       lift
# 8      (GREEN REGENCY TEACUP AND SAUCER)   0.0212    0.809160  25.286260
# 9       (PINK REGENCY TEACUP AND SAUCER)   0.0212    0.662500  25.286260
# 10     (GREEN REGENCY TEACUP AND SAUCER)   0.0248    0.765432  23.919753
# 11    (ROSES REGENCY TEACUP AND SAUCER )   0.0248    0.775000  23.919753
# 34    (ROSES REGENCY TEACUP AND SAUCER )   0.0202    0.770992  23.796061
# 35      (PINK REGENCY TEACUP AND SAUCER)   0.0202    0.623457  23.796061
# 3           (ALARM CLOCK BAKELIKE GREEN)   0.0230    0.653409  19.217914
# 2            (ALARM CLOCK BAKELIKE RED )   0.0230    0.676471  19.217914
# 7                  (SPACEBOY LUNCH BOX )   0.0206    0.602339  17.509860
# 6                 (DOLLY GIRL LUNCH BOX)   0.0206    0.598837  17.509860
# 38      (STRAWBERRY CERAMIC TRINKET BOX)   0.0264    0.741573  12.698168
# 39      (SWEETHEART CERAMIC TRINKET BOX)   0.0264    0.452055  12.698168
# 14            (HOME BUILDING BLOCK WORD)   0.0242    0.547511  10.735516
# 15            (LOVE BUILDING BLOCK WORD)   0.0242    0.474510  10.735516
# 42         (WOODEN FRAME ANTIQUE WHITE )   0.0280    0.585774  10.460251
# 43   (WOODEN PICTURE FRAME WHITE FINISH)   0.0280    0.500000  10.460251
# 12               (HEART OF WICKER SMALL)   0.0206    0.490476  10.133806
# 13               (HEART OF WICKER LARGE)   0.0206    0.425620  10.133806
# 0   (PACK OF 60 PINK PAISLEY CAKE CASES)   0.0240    0.447761   9.691801
# 1          (60 TEATIME FAIRY CAKE CASES)   0.0240    0.519481   9.691801
# 33                  (LUNCH BAG WOODLAND)   0.0200    0.401606   8.807158
# 32          (LUNCH BAG SPACEBOY DESIGN )   0.0200    0.438596   8.807158
# 31                  (LUNCH BAG WOODLAND)   0.0210    0.386029   8.465557
# 30             (LUNCH BAG  BLACK SKULL.)   0.0210    0.460526   8.465557
# 18             (JUMBO BAG RED RETROSPOT)   0.0216    0.692308   8.183306
# 19             (JUMBO BAG PINK POLKADOT)   0.0216    0.255319   8.183306
# 28             (LUNCH BAG  BLACK SKULL.)   0.0220    0.431373   7.929642
# 29                 (LUNCH BAG CARS BLUE)   0.0220    0.404412   7.929642
# 26              (JUMBO STORAGE BAG SUKI)   0.0228    0.419118   6.870781
# 27   (JUMBO SHOPPER VINTAGE RED PAISLEY)   0.0228    0.373770   6.870781
# 21             (JUMBO BAG RED RETROSPOT)   0.0224    0.520930   6.157568
# 20                (JUMBO BAG STRAWBERRY)   0.0224    0.264775   6.157568
# 17             (JUMBO BAG RED RETROSPOT)   0.0226    0.495614   5.858322
# 16      (JUMBO  BAG BAROQUE BLACK WHITE)   0.0226    0.267139   5.858322
# 22   (JUMBO SHOPPER VINTAGE RED PAISLEY)   0.0264    0.312057   5.736337
# 23             (JUMBO BAG RED RETROSPOT)   0.0264    0.485294   5.736337
# 24              (JUMBO STORAGE BAG SUKI)   0.0292    0.345154   5.658257
# 25             (JUMBO BAG RED RETROSPOT)   0.0292    0.478689   5.658257
# 37  (WHITE HANGING HEART T-LIGHT HOLDER)   0.0312    0.757282   5.393743
# 36    (RED HANGING HEART T-LIGHT HOLDER)   0.0312    0.222222   5.393743
# 41  (WHITE HANGING HEART T-LIGHT HOLDER)   0.0234    0.417857   2.976190

# %%
# number of transactions used (sampled invoices)
n_transactions = basket.shape[0]

# %%
# Build a readable result table
rules_out = rules[['antecedents','consequents','support','confidence','lift']].copy()
rules_out['antecedents'] = rules_out['antecedents'].apply(lambda s: ', '.join(sorted(list(s))))
rules_out['consequents'] = rules_out['consequents'].apply(lambda s: ', '.join(sorted(list(s))))
rules_out['support_count'] = (rules_out['support'] * n_transactions).round().astype(int)

# reorder columns for presentation
rules_out = rules_out[['antecedents','consequents','support_count','support','confidence','lift']]

# show results
print(rules_out)

# save to CSV for reporting
rules_out.to_csv('apriori_rules.csv', index=False)
# Out:
#                            antecedents                         consequents  \
# 8       PINK REGENCY TEACUP AND SAUCER     GREEN REGENCY TEACUP AND SAUCER
# 9      GREEN REGENCY TEACUP AND SAUCER      PINK REGENCY TEACUP AND SAUCER
# 10    ROSES REGENCY TEACUP AND SAUCER      GREEN REGENCY TEACUP AND SAUCER
# 11     GREEN REGENCY TEACUP AND SAUCER    ROSES REGENCY TEACUP AND SAUCER
# 34      PINK REGENCY TEACUP AND SAUCER    ROSES REGENCY TEACUP AND SAUCER
# 35    ROSES REGENCY TEACUP AND SAUCER       PINK REGENCY TEACUP AND SAUCER
# 3            ALARM CLOCK BAKELIKE RED           ALARM CLOCK BAKELIKE GREEN
# 2           ALARM CLOCK BAKELIKE GREEN           ALARM CLOCK BAKELIKE RED
# 7                 DOLLY GIRL LUNCH BOX                 SPACEBOY LUNCH BOX
# 6                  SPACEBOY LUNCH BOX                 DOLLY GIRL LUNCH BOX
# 38      SWEETHEART CERAMIC TRINKET BOX      STRAWBERRY CERAMIC TRINKET BOX
# 39      STRAWBERRY CERAMIC TRINKET BOX      SWEETHEART CERAMIC TRINKET BOX
# 14            LOVE BUILDING BLOCK WORD            HOME BUILDING BLOCK WORD
# 15            HOME BUILDING BLOCK WORD            LOVE BUILDING BLOCK WORD
# 42   WOODEN PICTURE FRAME WHITE FINISH         WOODEN FRAME ANTIQUE WHITE
# 43         WOODEN FRAME ANTIQUE WHITE    WOODEN PICTURE FRAME WHITE FINISH
# 12               HEART OF WICKER LARGE               HEART OF WICKER SMALL
# 13               HEART OF WICKER SMALL               HEART OF WICKER LARGE
# 0          60 TEATIME FAIRY CAKE CASES  PACK OF 60 PINK PAISLEY CAKE CASES
# 1   PACK OF 60 PINK PAISLEY CAKE CASES         60 TEATIME FAIRY CAKE CASES
# 33          LUNCH BAG SPACEBOY DESIGN                   LUNCH BAG WOODLAND
# 32                  LUNCH BAG WOODLAND          LUNCH BAG SPACEBOY DESIGN
# 31             LUNCH BAG  BLACK SKULL.                  LUNCH BAG WOODLAND
# 30                  LUNCH BAG WOODLAND             LUNCH BAG  BLACK SKULL.
# 18             JUMBO BAG PINK POLKADOT             JUMBO BAG RED RETROSPOT
# 19             JUMBO BAG RED RETROSPOT             JUMBO BAG PINK POLKADOT
# 28                 LUNCH BAG CARS BLUE             LUNCH BAG  BLACK SKULL.
# 29             LUNCH BAG  BLACK SKULL.                 LUNCH BAG CARS BLUE
# 26   JUMBO SHOPPER VINTAGE RED PAISLEY              JUMBO STORAGE BAG SUKI
# 27              JUMBO STORAGE BAG SUKI   JUMBO SHOPPER VINTAGE RED PAISLEY
# 21                JUMBO BAG STRAWBERRY             JUMBO BAG RED RETROSPOT
# 20             JUMBO BAG RED RETROSPOT                JUMBO BAG STRAWBERRY
# 17      JUMBO  BAG BAROQUE BLACK WHITE             JUMBO BAG RED RETROSPOT
# 16             JUMBO BAG RED RETROSPOT      JUMBO  BAG BAROQUE BLACK WHITE
# 22             JUMBO BAG RED RETROSPOT   JUMBO SHOPPER VINTAGE RED PAISLEY
# 23   JUMBO SHOPPER VINTAGE RED PAISLEY             JUMBO BAG RED RETROSPOT
# 24             JUMBO BAG RED RETROSPOT              JUMBO STORAGE BAG SUKI
# 25              JUMBO STORAGE BAG SUKI             JUMBO BAG RED RETROSPOT
# 37    RED HANGING HEART T-LIGHT HOLDER  WHITE HANGING HEART T-LIGHT HOLDER
# 36  WHITE HANGING HEART T-LIGHT HOLDER    RED HANGING HEART T-LIGHT HOLDER
# 41         WOODEN FRAME ANTIQUE WHITE   WHITE HANGING HEART T-LIGHT HOLDER
#
#     support_count  support  confidence       lift
# 8             106   0.0212    0.809160  25.286260
# 9             106   0.0212    0.662500  25.286260
# 10            124   0.0248    0.765432  23.919753
# 11            124   0.0248    0.775000  23.919753
# 34            101   0.0202    0.770992  23.796061
# 35            101   0.0202    0.623457  23.796061
# 3             115   0.0230    0.653409  19.217914
# 2             115   0.0230    0.676471  19.217914
# 7             103   0.0206    0.602339  17.509860
# 6             103   0.0206    0.598837  17.509860
# 38            132   0.0264    0.741573  12.698168
# 39            132   0.0264    0.452055  12.698168
# 14            121   0.0242    0.547511  10.735516
# 15            121   0.0242    0.474510  10.735516
# 42            140   0.0280    0.585774  10.460251
# 43            140   0.0280    0.500000  10.460251
# 12            103   0.0206    0.490476  10.133806
# 13            103   0.0206    0.425620  10.133806
# 0             120   0.0240    0.447761   9.691801
# 1             120   0.0240    0.519481   9.691801
# 33            100   0.0200    0.401606   8.807158
# 32            100   0.0200    0.438596   8.807158
# 31            105   0.0210    0.386029   8.465557
# 30            105   0.0210    0.460526   8.465557
# 18            108   0.0216    0.692308   8.183306
# 19            108   0.0216    0.255319   8.183306
# 28            110   0.0220    0.431373   7.929642
# 29            110   0.0220    0.404412   7.929642
# 26            114   0.0228    0.419118   6.870781
# 27            114   0.0228    0.373770   6.870781
# 21            112   0.0224    0.520930   6.157568
# 20            112   0.0224    0.264775   6.157568
# 17            113   0.0226    0.495614   5.858322
# 16            113   0.0226    0.267139   5.858322
# 22            132   0.0264    0.312057   5.736337
# 23            132   0.0264    0.485294   5.736337
# 24            146   0.0292    0.345154   5.658257
# 25            146   0.0292    0.478689   5.658257
# 37            156   0.0312    0.757282   5.393743
# 36            156   0.0312    0.222222   5.393743
# 41            117   0.0234    0.417857   2.976190
